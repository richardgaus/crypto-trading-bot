# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

from definitions import PROCESSED_DATA_DIR
from src.data.indicators import rsi, stochRSI, ema
from src.models.strategies import RSIStoch200EMA, BuyAndHold
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
btcusdt = pd.read_csv(PROCESSED_DATA_DIR / 'BTCUSDT.csv')
btcusdt.index = pd.DatetimeIndex(btcusdt['open time'])

btcusdt
# Out:
#                                open time      open      high       low  \
# open time
# 2017-08-17 20:30:00  2017-08-17 20:30:00   4301.91   4354.84   4262.53
# 2017-08-17 21:00:00  2017-08-17 21:00:00   4346.74   4369.69   4315.85
# 2017-08-17 21:30:00  2017-08-17 21:30:00   4349.33   4369.69   4309.23
# 2017-08-17 22:00:00  2017-08-17 22:00:00   4333.55   4349.63   4310.00
# 2017-08-17 22:30:00  2017-08-17 22:30:00   4326.29   4359.13   4319.11
# ...                                  ...       ...       ...       ...
# 2021-05-31 21:30:00  2021-05-31 21:30:00  36775.02  37087.30  36623.01
# 2021-05-31 22:00:00  2021-05-31 22:00:00  36932.55  37250.00  36863.28
# 2021-05-31 22:30:00  2021-05-31 22:30:00  37090.16  37140.00  36835.85
# 2021-05-31 23:00:00  2021-05-31 23:00:00  36879.23  37345.00  36800.93
# 2021-05-31 23:30:00  2021-05-31 23:30:00  37301.51  37499.00  37231.13
#
#                         close       volume           ema         rsi  \
# open time
# 2017-08-17 20:30:00   4346.74    15.184266   4346.740000         NaN
# 2017-08-17 21:00:00   4349.33    29.292665   4346.765771  100.000000
# 2017-08-17 21:30:00   4333.55    32.480371   4346.634271   13.225186
# 2017-08-17 22:00:00   4326.29    26.241174   4346.431840    9.248769
# 2017-08-17 22:30:00   4336.80    31.134968   4346.336001   38.211911
# ...                       ...          ...           ...         ...
# 2021-05-31 21:30:00  36932.55   840.717074  36229.710395   58.482794
# 2021-05-31 22:00:00  37090.16  1407.839699  36238.272082   61.498708
# 2021-05-31 22:30:00  36879.23   908.355699  36244.649773   55.670255
# 2021-05-31 23:00:00  37301.51  1160.566735  36255.165795   63.191393
# 2021-05-31 23:30:00  37253.81  1488.587448  36265.102554   61.913553
#
#                       stoch_k   stoch_d
# open time
# 2017-08-17 20:30:00       NaN       NaN
# 2017-08-17 21:00:00       NaN       NaN
# 2017-08-17 21:30:00       NaN       NaN
# 2017-08-17 22:00:00       NaN       NaN
# 2017-08-17 22:30:00       NaN       NaN
# ...                       ...       ...
# 2021-05-31 21:30:00  0.198487  0.133164
# 2021-05-31 22:00:00  0.419132  0.235186
# 2021-05-31 22:30:00  0.430699  0.349439
# 2021-05-31 23:00:00  0.580911  0.476914
# 2021-05-31 23:30:00  0.651560  0.554390
#
# [66391 rows x 10 columns]

# %%
strategy = RSIStoch200EMA(
    max_number_open_trades=3,
    min_period_to_last_low=5,
    max_period_to_last_low=50,
    min_absolute_slope_rsi=0.2,
    swing_low_margin=2
)

results = strategy.apply(
    ohlcv_timeseries=btcusdt.iloc[:1500],
    asset_name='BTCUSDT'
)

# %%
start_time = btcusdt.iloc[500].name
end_time = btcusdt.iloc[1000].name
results.plot(start_time, end_time)

# %%
buyandhold_strategy = BuyAndHold()
results = buyandhold_strategy.apply(
    ohlcv_timeseries=btcusdt,
    asset_name='BTCUSDT'
)
results.evaluation()
results.pnl
# Out:
# 7.570517215200358

# %%
strategy = RSIStoch200EMA(
    max_number_open_trades=3,
    min_period_to_last_low=5,
    max_period_to_last_low=50,
    min_absolute_slope_rsi=0.2,
    swing_low_margin=2
)

results = strategy.apply(
    ohlcv_timeseries=btcusdt.iloc[:1000],
    asset_name='BTCUSDT'
)

#start_time = btcusdt.iloc[200].name
#end_time = btcusdt.iloc[400].name
results.plot(btcusdt.iloc[0].name, btcusdt.iloc[500].name)

# %%
import numpy as np

max_number_open_trades=3

total = 1.0
num_positions = 0

# Convert trades to chronology of buy/sell events
events = []
for t in results.trades:
    # Calculate profit and loss of individual trade
    if t['win']:
        if t['entry_price'] > t['take_profit']:  # short trade
            pnl = - (t['take_profit'] / t['entry_price'] - 1.0)
        else:  # long trade
            pnl = t['take_profit'] / t['entry_price'] - 1.0
    else:
        if t['entry_price'] < t['stop_loss']:  # short trade
            pnl = - (t['stop_loss'] / t['entry_price'] - 1.0)
        else:  # long trade
            pnl = t['stop_loss'] / t['entry_price'] - 1.0
    events.append({
        'timestamp': t['entry_time'],
        'event': 'entry',
        'entry_time': t['entry_time'],
        'pnl': pnl,
        'investment': np.NaN
    })
    events.append({
        'timestamp': t['exit_time'],
        'event': 'exit',
        'entry_time': t['entry_time'],
        'pnl': pnl
    })
    events_df = pd.DataFrame(events)
    events_df = events_df.sort_values(by=['timestamp', 'event'], ascending=[True, False]).reset_index()

# %%
for idx, row in events_df.iterrows():
    
    s = ''
    if row['event'] == 'entry':
        investment = total / (max_number_open_trades - num_positions)
        events_df.loc[idx, 'investment'] = investment
        total -= investment

        s = f'investment: {investment:.4f}'

        num_positions += 1
    elif row['event'] == 'exit':
        total += events_df[(events_df['entry_time'] == row['entry_time']) & (events_df['event'] == 'entry')]['investment'].iloc[0] * \
            (1.0 + row['pnl'])
        num_positions -= 1
        
        s = f"outcome: {events_df[(events_df['entry_time'] == row['entry_time']) & (events_df['event'] == 'entry')]['investment'].iloc[0] * (1.0 + row['pnl']):.4f}"
    print(f"ts: {row['timestamp']} {row['event']}, num_pos: {num_positions}, {s}, total: {total}")
# Out:
# ts: 2017-08-19 01:30:00 entry, num_pos: 1, investment: 0.3333, total: 0.6666666666666667
# ts: 2017-08-19 04:30:00 exit, num_pos: 0, outcome: 0.3398, total: 1.0064833712182386
# ts: 2017-08-19 06:30:00 entry, num_pos: 1, investment: 0.3355, total: 0.6709889141454923
# ts: 2017-08-19 11:00:00 entry, num_pos: 2, investment: 0.3355, total: 0.33549445707274617
# ts: 2017-08-19 12:30:00 exit, num_pos: 1, outcome: 0.3249, total: 0.6603523711999079
# ts: 2017-08-19 21:00:00 entry, num_pos: 2, investment: 0.3302, total: 0.33017618559995393
# ts: 2017-08-20 00:00:00 exit, num_pos: 1, outcome: 0.3364, total: 0.6665413650670071
# ts: 2017-08-20 08:30:00 exit, num_pos: 0, outcome: 0.3185, total: 0.9850371605837713
# ts: 2017-08-20 12:30:00 entry, num_pos: 1, investment: 0.3283, total: 0.6566914403891808
# ts: 2017-08-20 22:00:00 entry, num_pos: 2, investment: 0.3283, total: 0.3283457201945904
# ts: 2017-08-20 23:30:00 exit, num_pos: 1, outcome: 0.3311, total: 0.6594688800541479
# ts: 2017-08-21 05:30:00 entry, num_pos: 2, investment: 0.3297, total: 0.32973444002707397
# ts: 2017-08-21 17:00:00 entry, num_pos: 3, investment: 0.3297, total: 0.0
# ts: 2017-08-21 17:30:00 exit, num_pos: 2, outcome: 0.3263, total: 0.3263000177591126
# ts: 2017-08-22 00:30:00 exit, num_pos: 1, outcome: 0.3454, total: 0.671719852864881
# ts: 2017-08-22 01:30:00 exit, num_pos: 0, outcome: 0.3558, total: 1.0275401000296454
# ts: 2017-08-22 08:00:00 entry, num_pos: 1, investment: 0.3425, total: 0.6850267333530968
# ts: 2017-08-22 08:30:00 exit, num_pos: 0, outcome: 0.3460, total: 1.0310565456519893
# ts: 2017-08-22 22:30:00 entry, num_pos: 1, investment: 0.3437, total: 0.6873710304346596
# ts: 2017-08-23 00:00:00 exit, num_pos: 0, outcome: 0.3395, total: 1.026920974068728
# ts: 2017-08-23 07:30:00 entry, num_pos: 1, investment: 0.3423, total: 0.6846139827124853
# ts: 2017-08-23 09:00:00 exit, num_pos: 0, outcome: 0.3496, total: 1.03424535310635
# ts: 2017-08-23 19:00:00 entry, num_pos: 1, investment: 0.3447, total: 0.6894969020709001
# ts: 2017-08-23 20:00:00 exit, num_pos: 0, outcome: 0.3400, total: 1.0295009047538968
# ts: 2017-08-23 22:00:00 entry, num_pos: 1, investment: 0.3432, total: 0.6863339365025978
# ts: 2017-08-23 22:30:00 exit, num_pos: 0, outcome: 0.3471, total: 1.033436753394504
# ts: 2017-08-23 23:00:00 entry, num_pos: 1, investment: 0.3445, total: 0.6889578355963359
# ts: 2017-08-24 02:30:00 entry, num_pos: 2, investment: 0.3445, total: 0.34447891779816797
# ts: 2017-08-24 03:00:00 exit, num_pos: 1, outcome: 0.3426, total: 0.6871125283496677
# ts: 2017-08-24 12:00:00 entry, num_pos: 2, investment: 0.3436, total: 0.34355626417483387
# ts: 2017-08-24 14:30:00 exit, num_pos: 1, outcome: 0.3528, total: 0.6963162128971623
# ts: 2017-08-24 20:30:00 entry, num_pos: 2, investment: 0.3482, total: 0.34815810644858114
# ts: 2017-08-24 21:00:00 exit, num_pos: 1, outcome: 0.3489, total: 0.697067269676628
# ts: 2017-08-24 22:30:00 exit, num_pos: 0, outcome: 0.3581, total: 1.0551911695867837
# ts: 2017-08-25 05:00:00 entry, num_pos: 1, investment: 0.3517, total: 0.7034607797245225
# ts: 2017-08-25 05:30:00 exit, num_pos: 0, outcome: 0.3482, total: 1.0517068191150334
# ts: 2017-08-25 21:00:00 entry, num_pos: 1, investment: 0.3506, total: 0.7011378794100223
# ts: 2017-08-25 21:30:00 exit, num_pos: 0, outcome: 0.3548, total: 1.0559143657852208
# ts: 2017-08-26 01:00:00 entry, num_pos: 1, investment: 0.3520, total: 0.7039429105234805
# ts: 2017-08-26 02:00:00 exit, num_pos: 0, outcome: 0.3489, total: 1.052803717467223
# ts: 2017-08-27 05:00:00 entry, num_pos: 1, investment: 0.3509, total: 0.7018691449781487
# ts: 2017-08-27 09:00:00 entry, num_pos: 2, investment: 0.3509, total: 0.35093457248907434
# ts: 2017-08-27 10:30:00 exit, num_pos: 1, outcome: 0.3484, total: 0.6993147741182726
# ts: 2017-08-28 04:00:00 exit, num_pos: 0, outcome: 0.3420, total: 1.041333353102548
# ts: 2017-08-28 09:00:00 entry, num_pos: 1, investment: 0.3471, total: 0.6942222354016987
# ts: 2017-08-28 10:30:00 exit, num_pos: 0, outcome: 0.3417, total: 1.0359057537134746
# ts: 2017-08-28 10:30:00 entry, num_pos: 1, investment: 0.3453, total: 0.690603835808983
# ts: 2017-08-28 12:00:00 entry, num_pos: 2, investment: 0.3453, total: 0.3453019179044915
# ts: 2017-08-29 03:00:00 entry, num_pos: 3, investment: 0.3453, total: 0.0
# ts: 2017-08-29 12:30:00 exit, num_pos: 2, outcome: 0.3563, total: 0.3562573601560552
# ts: 2017-08-29 12:30:00 exit, num_pos: 1, outcome: 0.3561, total: 0.7123134955866601
# ts: 2017-08-29 13:30:00 exit, num_pos: 0, outcome: 0.3570, total: 1.0692653391946225
# ts: 2017-08-30 01:30:00 entry, num_pos: 1, investment: 0.3564, total: 0.7128435594630818
# ts: 2017-08-30 04:00:00 entry, num_pos: 2, investment: 0.3564, total: 0.3564217797315409
# ts: 2017-08-30 05:00:00 exit, num_pos: 1, outcome: 0.3541, total: 0.7105448374846487
# ts: 2017-08-30 05:30:00 entry, num_pos: 2, investment: 0.3553, total: 0.35527241874232435
# ts: 2017-08-30 07:00:00 exit, num_pos: 1, outcome: 0.3530, total: 0.7082443009652327
# ts: 2017-08-30 07:30:00 entry, num_pos: 2, investment: 0.3541, total: 0.35412215048261636
# ts: 2017-08-30 08:00:00 exit, num_pos: 1, outcome: 0.3548, total: 0.7089541002836631
# ts: 2017-08-30 09:30:00 exit, num_pos: 0, outcome: 0.3506, total: 1.0595904402601548
# ts: 2017-08-30 11:00:00 entry, num_pos: 1, investment: 0.3532, total: 0.7063936268401032
# ts: 2017-08-31 17:00:00 entry, num_pos: 2, investment: 0.3532, total: 0.3531968134200516
# ts: 2017-08-31 17:30:00 entry, num_pos: 3, investment: 0.3532, total: 0.0
# ts: 2017-09-01 10:00:00 exit, num_pos: 2, outcome: 0.3719, total: 0.371933906710108
# ts: 2017-09-01 13:00:00 exit, num_pos: 1, outcome: 0.3662, total: 0.7381206891467091
# ts: 2017-09-01 21:30:00 entry, num_pos: 2, investment: 0.3691, total: 0.36906034457335457
# ts: 2017-09-01 22:30:00 exit, num_pos: 1, outcome: 0.3747, total: 0.7437354026621359
# ts: 2017-09-02 01:30:00 exit, num_pos: 0, outcome: 0.3712, total: 1.1149445538803207
# ts: 2017-09-02 05:00:00 entry, num_pos: 1, investment: 0.3716, total: 0.743296369253547
# ts: 2017-09-02 05:30:00 exit, num_pos: 0, outcome: 0.3673, total: 1.1105958308998223
# ts: 2017-09-02 08:00:00 entry, num_pos: 1, investment: 0.3702, total: 0.7403972205998814
# ts: 2017-09-02 20:00:00 exit, num_pos: 0, outcome: 0.3952, total: 1.135628209328072
# ts: 2017-09-03 01:00:00 entry, num_pos: 1, investment: 0.3785, total: 0.7570854728853813
# ts: 2017-09-03 04:00:00 exit, num_pos: 0, outcome: 0.3724, total: 1.1295042958091575
# ts: 2017-09-03 05:30:00 entry, num_pos: 1, investment: 0.3765, total: 0.7530028638727717
# ts: 2017-09-03 11:30:00 exit, num_pos: 0, outcome: 0.3595, total: 1.1124548254271744
# ts: 2017-09-03 18:00:00 entry, num_pos: 1, investment: 0.3708, total: 0.741636550284783
# ts: 2017-09-03 20:00:00 exit, num_pos: 0, outcome: 0.3622, total: 1.1038744127218252
# ts: 2017-09-04 21:00:00 entry, num_pos: 1, investment: 0.3680, total: 0.7359162751478834
# ts: 2017-09-04 21:30:00 exit, num_pos: 0, outcome: 0.3668, total: 1.102712300010264
# ts: 2017-09-04 21:30:00 entry, num_pos: 1, investment: 0.3676, total: 0.7351415333401761
# ts: 2017-09-04 22:00:00 exit, num_pos: 0, outcome: 0.3757, total: 1.1108003328914975
# ts: 2017-09-05 08:00:00 entry, num_pos: 1, investment: 0.3703, total: 0.7405335552609984
# ts: 2017-09-05 09:00:00 exit, num_pos: 0, outcome: 0.3803, total: 1.120836603699789
# ts: 2017-09-07 02:30:00 entry, num_pos: 1, investment: 0.3736, total: 0.747224402466526
# ts: 2017-09-07 11:00:00 exit, num_pos: 0, outcome: 0.3846, total: 1.131828926496068

# %%
total
# Out:
# 1.131828926496068

# %%
for index, row in events_df.iterrows():
    print(a)
# Out:
# (0, timestamp     2017-08-19 01:30:00
# event                       entry
# entry_time    2017-08-19 01:30:00
# pnl                       0.01945
# Name: 0, dtype: object)
# (1, timestamp     2017-08-19 04:30:00
# event                        exit
# entry_time    2017-08-19 01:30:00
# pnl                           NaN
# Name: 1, dtype: object)
# (2, timestamp     2017-08-19 06:30:00
# event                       entry
# entry_time    2017-08-19 06:30:00
# pnl                     -0.050667
# Name: 2, dtype: object)
# (3, timestamp     2017-08-20 08:30:00
# event                        exit
# entry_time    2017-08-19 06:30:00
# pnl                           NaN
# Name: 3, dtype: object)
# (4, timestamp     2017-08-19 11:00:00
# event                       entry
# entry_time    2017-08-19 11:00:00
# pnl                     -0.031704
# Name: 4, dtype: object)
# (5, timestamp     2017-08-19 12:30:00
# event                        exit
# entry_time    2017-08-19 11:00:00
# pnl                           NaN
# Name: 5, dtype: object)
# (6, timestamp     2017-08-19 21:00:00
# event                       entry
# entry_time    2017-08-19 21:00:00
# pnl                      0.018745
# Name: 6, dtype: object)
# (7, timestamp     2017-08-20 00:00:00
# event                        exit
# entry_time    2017-08-19 21:00:00
# pnl                           NaN
# Name: 7, dtype: object)
# (8, timestamp     2017-08-20 12:30:00
# event                       entry
# entry_time    2017-08-20 12:30:00
# pnl                         0.052
# Name: 8, dtype: object)
# (9, timestamp     2017-08-22 00:30:00
# event                        exit
# entry_time    2017-08-20 12:30:00
# pnl                           NaN
# Name: 9, dtype: object)
# (10, timestamp     2017-08-20 22:00:00
# event                       entry
# entry_time    2017-08-20 22:00:00
# pnl                      0.008459
# Name: 10, dtype: object)
# (11, timestamp     2017-08-20 23:30:00
# event                        exit
# entry_time    2017-08-20 22:00:00
# pnl                           NaN
# Name: 11, dtype: object)
# (12, timestamp     2017-08-21 05:30:00
# event                       entry
# entry_time    2017-08-21 05:30:00
# pnl                      0.079112
# Name: 12, dtype: object)
# (13, timestamp     2017-08-22 01:30:00
# event                        exit
# entry_time    2017-08-21 05:30:00
# pnl                           NaN
# Name: 13, dtype: object)
# (14, timestamp     2017-08-21 17:00:00
# event                       entry
# entry_time    2017-08-21 17:00:00
# pnl                     -0.010416
# Name: 14, dtype: object)
# (15, timestamp     2017-08-21 17:30:00
# event                        exit
# entry_time    2017-08-21 17:00:00
# pnl                           NaN
# Name: 15, dtype: object)
# (16, timestamp     2017-08-22 08:00:00
# event                       entry
# entry_time    2017-08-22 08:00:00
# pnl                      0.010267
# Name: 16, dtype: object)
# (17, timestamp     2017-08-22 08:30:00
# event                        exit
# entry_time    2017-08-22 08:00:00
# pnl                           NaN
# Name: 17, dtype: object)
# (18, timestamp     2017-08-22 22:30:00
# event                       entry
# entry_time    2017-08-22 22:30:00
# pnl                     -0.012033
# Name: 18, dtype: object)
# (19, timestamp     2017-08-23 00:00:00
# event                        exit
# entry_time    2017-08-22 22:30:00
# pnl                           NaN
# Name: 19, dtype: object)
# (20, timestamp     2017-08-23 07:30:00
# event                       entry
# entry_time    2017-08-23 07:30:00
# pnl                      0.021397
# Name: 20, dtype: object)
# (21, timestamp     2017-08-23 09:00:00
# event                        exit
# entry_time    2017-08-23 07:30:00
# pnl                           NaN
# Name: 21, dtype: object)
# (22, timestamp     2017-08-23 19:00:00
# event                       entry
# entry_time    2017-08-23 19:00:00
# pnl                     -0.013762
# Name: 22, dtype: object)
# (23, timestamp     2017-08-23 20:00:00
# event                        exit
# entry_time    2017-08-23 19:00:00
# pnl                           NaN
# Name: 23, dtype: object)
# (24, timestamp     2017-08-23 22:00:00
# event                       entry
# entry_time    2017-08-23 22:00:00
# pnl                      0.011469
# Name: 24, dtype: object)
# (25, timestamp     2017-08-23 22:30:00
# event                        exit
# entry_time    2017-08-23 22:00:00
# pnl                           NaN
# Name: 25, dtype: object)
# (26, timestamp     2017-08-23 23:00:00
# event                       entry
# entry_time    2017-08-23 23:00:00
# pnl                       0.03961
# Name: 26, dtype: object)
# (27, timestamp     2017-08-24 22:30:00
# event                        exit
# entry_time    2017-08-23 23:00:00
# pnl                           NaN
# Name: 27, dtype: object)
# (28, timestamp     2017-08-24 02:30:00
# event                       entry
# entry_time    2017-08-24 02:30:00
# pnl                     -0.005357
# Name: 28, dtype: object)
# (29, timestamp     2017-08-24 03:00:00
# event                        exit
# entry_time    2017-08-24 02:30:00
# pnl                           NaN
# Name: 29, dtype: object)
# (30, timestamp     2017-08-24 12:00:00
# event                       entry
# entry_time    2017-08-24 12:00:00
# pnl                      0.026789
# Name: 30, dtype: object)
# (31, timestamp     2017-08-24 14:30:00
# event                        exit
# entry_time    2017-08-24 12:00:00
# pnl                           NaN
# Name: 31, dtype: object)
# (32, timestamp     2017-08-24 20:30:00
# event                       entry
# entry_time    2017-08-24 20:30:00
# pnl                      0.002157
# Name: 32, dtype: object)
# (33, timestamp     2017-08-24 21:00:00
# event                        exit
# entry_time    2017-08-24 20:30:00
# pnl                           NaN
# Name: 33, dtype: object)
# (34, timestamp     2017-08-25 05:00:00
# event                       entry
# entry_time    2017-08-25 05:00:00
# pnl                     -0.009906
# Name: 34, dtype: object)
# (35, timestamp     2017-08-25 05:30:00
# event                        exit
# entry_time    2017-08-25 05:00:00
# pnl                           NaN
# Name: 35, dtype: object)
# (36, timestamp     2017-08-25 21:00:00
# event                       entry
# entry_time    2017-08-25 21:00:00
# pnl                      0.012002
# Name: 36, dtype: object)
# (37, timestamp     2017-08-25 21:30:00
# event                        exit
# entry_time    2017-08-25 21:00:00
# pnl                           NaN
# Name: 37, dtype: object)
# (38, timestamp     2017-08-26 01:00:00
# event                       entry
# entry_time    2017-08-26 01:00:00
# pnl                     -0.008838
# Name: 38, dtype: object)
# (39, timestamp     2017-08-26 02:00:00
# event                        exit
# entry_time    2017-08-26 01:00:00
# pnl                           NaN
# Name: 39, dtype: object)
# (40, timestamp     2017-08-27 05:00:00
# event                       entry
# entry_time    2017-08-27 05:00:00
# pnl                     -0.025406
# Name: 40, dtype: object)
# (41, timestamp     2017-08-28 04:00:00
# event                        exit
# entry_time    2017-08-27 05:00:00
# pnl                           NaN
# Name: 41, dtype: object)
# (42, timestamp     2017-08-27 09:00:00
# event                       entry
# entry_time    2017-08-27 09:00:00
# pnl                     -0.007279
# Name: 42, dtype: object)
# (43, timestamp     2017-08-27 10:30:00
# event                        exit
# entry_time    2017-08-27 09:00:00
# pnl                           NaN
# Name: 43, dtype: object)
# (44, timestamp     2017-08-28 09:00:00
# event                       entry
# entry_time    2017-08-28 09:00:00
# pnl                     -0.015636
# Name: 44, dtype: object)
# (45, timestamp     2017-08-28 10:30:00
# event                        exit
# entry_time    2017-08-28 09:00:00
# pnl                           NaN
# Name: 45, dtype: object)
# (46, timestamp     2017-08-28 10:30:00
# event                       entry
# entry_time    2017-08-28 10:30:00
# pnl                      0.031727
# Name: 46, dtype: object)
# (47, timestamp     2017-08-29 12:30:00
# event                        exit
# entry_time    2017-08-28 10:30:00
# pnl                           NaN
# Name: 47, dtype: object)
# (48, timestamp     2017-08-28 12:00:00
# event                       entry
# entry_time    2017-08-28 12:00:00
# pnl                      0.031144
# Name: 48, dtype: object)
# (49, timestamp     2017-08-29 12:30:00
# event                        exit
# entry_time    2017-08-28 12:00:00
# pnl                           NaN
# Name: 49, dtype: object)
# (50, timestamp     2017-08-29 03:00:00
# event                       entry
# entry_time    2017-08-29 03:00:00
# pnl                      0.033738
# Name: 50, dtype: object)
# (51, timestamp     2017-08-29 13:30:00
# event                        exit
# entry_time    2017-08-29 03:00:00
# pnl                           NaN
# Name: 51, dtype: object)
# (52, timestamp     2017-08-30 01:30:00
# event                       entry
# entry_time    2017-08-30 01:30:00
# pnl                     -0.016232
# Name: 52, dtype: object)
# (53, timestamp     2017-08-30 09:30:00
# event                        exit
# entry_time    2017-08-30 01:30:00
# pnl                           NaN
# Name: 53, dtype: object)
# (54, timestamp     2017-08-30 04:00:00
# event                       entry
# entry_time    2017-08-30 04:00:00
# pnl                     -0.006449
# Name: 54, dtype: object)
# (55, timestamp     2017-08-30 05:00:00
# event                        exit
# entry_time    2017-08-30 04:00:00
# pnl                           NaN
# Name: 55, dtype: object)
# (56, timestamp     2017-08-30 05:30:00
# event                       entry
# entry_time    2017-08-30 05:30:00
# pnl                     -0.006475
# Name: 56, dtype: object)
# (57, timestamp     2017-08-30 07:00:00
# event                        exit
# entry_time    2017-08-30 05:30:00
# pnl                           NaN
# Name: 57, dtype: object)
# (58, timestamp     2017-08-30 07:30:00
# event                       entry
# entry_time    2017-08-30 07:30:00
# pnl                      0.002004
# Name: 58, dtype: object)
# (59, timestamp     2017-08-30 08:00:00
# event                        exit
# entry_time    2017-08-30 07:30:00
# pnl                           NaN
# Name: 59, dtype: object)
# (60, timestamp     2017-08-30 11:00:00
# event                       entry
# entry_time    2017-08-30 11:00:00
# pnl                       0.05305
# Name: 60, dtype: object)
# (61, timestamp     2017-09-01 10:00:00
# event                        exit
# entry_time    2017-08-30 11:00:00
# pnl                           NaN
# Name: 61, dtype: object)
# (62, timestamp     2017-08-31 17:00:00
# event                       entry
# entry_time    2017-08-31 17:00:00
# pnl                      0.050998
# Name: 62, dtype: object)
# (63, timestamp     2017-09-02 01:30:00
# event                        exit
# entry_time    2017-08-31 17:00:00
# pnl                           NaN
# Name: 63, dtype: object)
# (64, timestamp     2017-08-31 17:30:00
# event                       entry
# entry_time    2017-08-31 17:30:00
# pnl                      0.036778
# Name: 64, dtype: object)
# (65, timestamp     2017-09-01 13:00:00
# event                        exit
# entry_time    2017-08-31 17:30:00
# pnl                           NaN
# Name: 65, dtype: object)
# (66, timestamp     2017-09-01 21:30:00
# event                       entry
# entry_time    2017-09-01 21:30:00
# pnl                      0.015214
# Name: 66, dtype: object)
# (67, timestamp     2017-09-01 22:30:00
# event                        exit
# entry_time    2017-09-01 21:30:00
# pnl                           NaN
# Name: 67, dtype: object)
# (68, timestamp     2017-09-02 05:00:00
# event                       entry
# entry_time    2017-09-02 05:00:00
# pnl                     -0.011701
# Name: 68, dtype: object)
# (69, timestamp     2017-09-02 05:30:00
# event                        exit
# entry_time    2017-09-02 05:00:00
# pnl                           NaN
# Name: 69, dtype: object)
# (70, timestamp     2017-09-02 08:00:00
# event                       entry
# entry_time    2017-09-02 08:00:00
# pnl                      0.067619
# Name: 70, dtype: object)
# (71, timestamp     2017-09-02 20:00:00
# event                        exit
# entry_time    2017-09-02 08:00:00
# pnl                           NaN
# Name: 71, dtype: object)
# (72, timestamp     2017-09-03 01:00:00
# event                       entry
# entry_time    2017-09-03 01:00:00
# pnl                     -0.016178
# Name: 72, dtype: object)
# (73, timestamp     2017-09-03 04:00:00
# event                        exit
# entry_time    2017-09-03 01:00:00
# pnl                           NaN
# Name: 73, dtype: object)
# (74, timestamp     2017-09-03 05:30:00
# event                       entry
# entry_time    2017-09-03 05:30:00
# pnl                     -0.045284
# Name: 74, dtype: object)
# (75, timestamp     2017-09-03 11:30:00
# event                        exit
# entry_time    2017-09-03 05:30:00
# pnl                           NaN
# Name: 75, dtype: object)
# (76, timestamp     2017-09-03 18:00:00
# event                       entry
# entry_time    2017-09-03 18:00:00
# pnl                     -0.023139
# Name: 76, dtype: object)
# (77, timestamp     2017-09-03 20:00:00
# event                        exit
# entry_time    2017-09-03 18:00:00
# pnl                           NaN
# Name: 77, dtype: object)
# (78, timestamp     2017-09-04 21:00:00
# event                       entry
# entry_time    2017-09-04 21:00:00
# pnl                     -0.003158
# Name: 78, dtype: object)
# (79, timestamp     2017-09-04 21:30:00
# event                        exit
# entry_time    2017-09-04 21:00:00
# pnl                           NaN
# Name: 79, dtype: object)
# (80, timestamp     2017-09-04 21:30:00
# event                       entry
# entry_time    2017-09-04 21:30:00
# pnl                      0.022004
# Name: 80, dtype: object)
# (81, timestamp     2017-09-04 22:00:00
# event                        exit
# entry_time    2017-09-04 21:30:00
# pnl                           NaN
# Name: 81, dtype: object)
# (82, timestamp     2017-09-05 08:00:00
# event                       entry
# entry_time    2017-09-05 08:00:00
# pnl                      0.027106
# Name: 82, dtype: object)
# (83, timestamp     2017-09-05 09:00:00
# event                        exit
# entry_time    2017-09-05 08:00:00
# pnl                           NaN
# Name: 83, dtype: object)
# (84, timestamp     2017-09-07 02:30:00
# event                       entry
# entry_time    2017-09-07 02:30:00
# pnl                      0.029422
# Name: 84, dtype: object)
# (85, timestamp     2017-09-07 11:00:00
# event                        exit
# entry_time    2017-09-07 02:30:00
# pnl                           NaN
# Name: 85, dtype: object)
# (86, timestamp     2017-09-07 19:30:00
# event                       entry
# entry_time    2017-09-07 19:30:00
# pnl                     -0.016592
# Name: 86, dtype: object)
# (87, timestamp     2017-09-07 20:00:00
# event                        exit
# entry_time    2017-09-07 19:30:00
# pnl                           NaN
# Name: 87, dtype: object)
# (88, timestamp     2017-09-08 09:00:00
# event                       entry
# entry_time    2017-09-08 09:00:00
# pnl                     -0.016791
# Name: 88, dtype: object)
# (89, timestamp     2017-09-08 13:00:00
# event                        exit
# entry_time    2017-09-08 09:00:00
# pnl                           NaN
# Name: 89, dtype: object)
# (90, timestamp     2017-09-08 23:30:00
# event                       entry
# entry_time    2017-09-08 23:30:00
# pnl                      0.026004
# Name: 90, dtype: object)
# (91, timestamp     2017-09-09 02:00:00
# event                        exit
# entry_time    2017-09-08 23:30:00
# pnl                           NaN
# Name: 91, dtype: object)
# (92, timestamp     2017-09-10 09:30:00
# event                       entry
# entry_time    2017-09-10 09:30:00
# pnl                      -0.02423
# Name: 92, dtype: object)
# (93, timestamp     2017-09-10 13:30:00
# event                        exit
# entry_time    2017-09-10 09:30:00
# pnl                           NaN
# Name: 93, dtype: object)
# (94, timestamp     2017-09-10 11:30:00
# event                       entry
# entry_time    2017-09-10 11:30:00
# pnl                      0.002591
# Name: 94, dtype: object)
# (95, timestamp     2017-09-10 12:00:00
# event                        exit
# entry_time    2017-09-10 11:30:00
# pnl                           NaN
# Name: 95, dtype: object)
# (96, timestamp     2017-09-10 15:30:00
# event                       entry
# entry_time    2017-09-10 15:30:00
# pnl                     -0.010912
# Name: 96, dtype: object)
# (97, timestamp     2017-09-10 17:00:00
# event                        exit
# entry_time    2017-09-10 15:30:00
# pnl                           NaN
# Name: 97, dtype: object)
# (98, timestamp     2017-09-11 01:00:00
# event                       entry
# entry_time    2017-09-11 01:00:00
# pnl                     -0.002438
# Name: 98, dtype: object)
# (99, timestamp     2017-09-11 01:30:00
# event                        exit
# entry_time    2017-09-11 01:00:00
# pnl                           NaN
# Name: 99, dtype: object)
# (100, timestamp     2017-09-12 10:00:00
# event                       entry
# entry_time    2017-09-12 10:00:00
# pnl                     -0.018932
# Name: 100, dtype: object)
# (101, timestamp     2017-09-12 16:00:00
# event                        exit
# entry_time    2017-09-12 10:00:00
# pnl                           NaN
# Name: 101, dtype: object)
# (102, timestamp     2017-09-12 14:30:00
# event                       entry
# entry_time    2017-09-12 14:30:00
# pnl                     -0.011055
# Name: 102, dtype: object)
# (103, timestamp     2017-09-12 16:00:00
# event                        exit
# entry_time    2017-09-12 14:30:00
# pnl                           NaN
# Name: 103, dtype: object)
# (104, timestamp     2017-09-12 16:00:00
# event                       entry
# entry_time    2017-09-12 16:00:00
# pnl                      0.070868
# Name: 104, dtype: object)
# (105, timestamp     2017-09-13 03:30:00
# event                        exit
# entry_time    2017-09-12 16:00:00
# pnl                           NaN
# Name: 105, dtype: object)
# (106, timestamp     2017-09-13 18:30:00
# event                       entry
# entry_time    2017-09-13 18:30:00
# pnl                      0.048193
# Name: 106, dtype: object)
# (107, timestamp     2017-09-14 10:30:00
# event                        exit
# entry_time    2017-09-13 18:30:00
# pnl                           NaN
# Name: 107, dtype: object)
# (108, timestamp     2017-09-14 16:00:00
# event                       entry
# entry_time    2017-09-14 16:00:00
# pnl                      0.065329
# Name: 108, dtype: object)
# (109, timestamp     2017-09-14 18:00:00
# event                        exit
# entry_time    2017-09-14 16:00:00
# pnl                           NaN
# Name: 109, dtype: object)
# (110, timestamp     2017-09-15 02:30:00
# event                       entry
# entry_time    2017-09-15 02:30:00
# pnl                      0.043339
# Name: 110, dtype: object)
# (111, timestamp     2017-09-15 05:00:00
# event                        exit
# entry_time    2017-09-15 02:30:00
# pnl                           NaN
# Name: 111, dtype: object)
# (112, timestamp     2017-09-15 15:00:00
# event                       entry
# entry_time    2017-09-15 15:00:00
# pnl                     -0.069787
# Name: 112, dtype: object)
# (113, timestamp     2017-09-16 01:30:00
# event                        exit
# entry_time    2017-09-15 15:00:00
# pnl                           NaN
# Name: 113, dtype: object)
# (114, timestamp     2017-09-16 06:00:00
# event                       entry
# entry_time    2017-09-16 06:00:00
# pnl                      0.009535
# Name: 114, dtype: object)
# (115, timestamp     2017-09-16 06:30:00
# event                        exit
# entry_time    2017-09-16 06:00:00
# pnl                           NaN
# Name: 115, dtype: object)
# (116, timestamp     2017-09-16 11:00:00
# event                       entry
# entry_time    2017-09-16 11:00:00
# pnl                     -0.067548
# Name: 116, dtype: object)
# (117, timestamp     2017-09-18 01:30:00
# event                        exit
# entry_time    2017-09-16 11:00:00
# pnl                           NaN
# Name: 117, dtype: object)
# (118, timestamp     2017-09-17 15:00:00
# event                       entry
# entry_time    2017-09-17 15:00:00
# pnl                      -0.00922
# Name: 118, dtype: object)
# (119, timestamp     2017-09-17 16:00:00
# event                        exit
# entry_time    2017-09-17 15:00:00
# pnl                           NaN
# Name: 119, dtype: object)

# %%
results.plot(pd.Timestamp('2017-08-28 04:00:00'), pd.Timestamp('2017-08-29 13:30:00'))#pd.Timestamp('2017-09-01 13:00:00'))

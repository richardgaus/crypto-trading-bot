# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np

from definitions import RAW_DATA_DIR
from src.models.strategies import RSIStoch200EMAResults
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
btcusdt = pd.read_csv(RAW_DATA_DIR / 'BTCUSDT.csv')
btcusdt.index = pd.DatetimeIndex(btcusdt['open time'])

# %%
from src.data.indicators import rsi, stochRSI, ema

# %%
btcusdt['rsi'] = rsi(ohlc=btcusdt, period=14)
btcusdt['stoch_k'], btcusdt['stoch_d'] = stochRSI(
    ohlc=btcusdt, period=14, smoothK=3, smoothD=3
)
btcusdt['ema'] = ema(ohlc=btcusdt, period=200)

# %%
btcusdt
# Out:
#                                open time      open      high       low  \
# open time
# 2017-08-17 20:30:00  2017-08-17 20:30:00   4301.91   4354.84   4262.53
# 2017-08-17 21:00:00  2017-08-17 21:00:00   4346.74   4369.69   4315.85
# 2017-08-17 21:30:00  2017-08-17 21:30:00   4349.33   4369.69   4309.23
# 2017-08-17 22:00:00  2017-08-17 22:00:00   4333.55   4349.63   4310.00
# 2017-08-17 22:30:00  2017-08-17 22:30:00   4326.29   4359.13   4319.11
# ...                                  ...       ...       ...       ...
# 2021-05-31 21:30:00  2021-05-31 21:30:00  36775.02  37087.30  36623.01
# 2021-05-31 22:00:00  2021-05-31 22:00:00  36932.55  37250.00  36863.28
# 2021-05-31 22:30:00  2021-05-31 22:30:00  37090.16  37140.00  36835.85
# 2021-05-31 23:00:00  2021-05-31 23:00:00  36879.23  37345.00  36800.93
# 2021-05-31 23:30:00  2021-05-31 23:30:00  37301.51  37499.00  37231.13
#
#                         close       volume         rsi   stoch_k   stoch_d  \
# open time
# ...

# %%
results = RSIStoch200EMAResults(
    asset_name='BTCUSDT',
    ohlcv_timeseries=btcusdt
)

start_time = btcusdt.index[-3000]
end_time = btcusdt.index[-1000]
fin_data = btcusdt[start_time:end_time]


min_period_to_last_low = 5
max_period_to_last_low = 50

swing_low_margin = 2

running_bullish_divergences = []
running_bearish_divergences = []
true_divergence = None
wait_for_stoch_cross = False
current_pattern = {}
current_trade = {}

for idx in range(1, len(fin_data)-1):
    row = fin_data.iloc[idx]
    if np.isnan(row['ema']) or np.isnan(row['rsi']) or \
       np.isnan(row['stoch_k']) or np.isnan(row['stoch_d']):
        continue
    if np.isnan(fin_data.iloc[idx-1]['rsi']):
        continue
        
    for potential_div in running_bullish_divergences:
        # Update threshold
        threshold = potential_div['t1_rsi'] + (idx - potential_div['t1_idx']) * potential_div['slope']
        potential_div['threshold'] = threshold
        # Scan for lower RSI value
        if row['rsi'] < potential_div['threshold']:
            # Update slope
            delta_y = row['rsi'] - potential_div['t1_rsi']
            delta_x = idx - potential_div['t1_idx']
            potential_div['slope'] = delta_y / delta_x
            # Is this a local low on RSI? -> potential bullish divergence spotted
            if (row['rsi'] < fin_data.iloc[idx-1]['rsi']) and (row['rsi'] < fin_data.iloc[idx+1]['rsi']):
                if min_period_to_last_low <= idx - potential_div['t1_idx'] <= max_period_to_last_low:
                    past_row = fin_data.loc[potential_div['t1']]
                    # Check if there is a higher low on price
                    if not wait_for_stoch_cross and \
                        min(past_row['close'], past_row['open']) < min(row['close'], row['open']):
                        # Divergence found!
                        wait_for_stoch_cross = True
                        potential_div['t2'] = row.name
                        potential_div['t2_idx'] = idx
                        potential_div['t2_rsi'] = row['rsi']
                        true_divergence = potential_div
                        
    for potential_div in running_bearish_divergences:
        # Update threshold
        threshold = potential_div['t1_rsi'] + (idx - potential_div['t1_idx']) * potential_div['slope']
        potential_div['threshold'] = threshold
        # Scan for higher RSI value
        if row['rsi'] > potential_div['threshold']:
            # Update slope
            delta_y = row['rsi'] - potential_div['t1_rsi']
            delta_x = idx - potential_div['t1_idx']
            potential_div['slope'] = delta_y / delta_x
            # Is this a local high on RSI? -> potential bearish divergence spotted
            if (row['rsi'] > fin_data.iloc[idx-1]['rsi']) and (row['rsi'] > fin_data.iloc[idx+1]['rsi']):
                if min_period_to_last_low <= idx - potential_div['t1_idx'] <= max_period_to_last_low:
                    past_row = fin_data.loc[potential_div['t1']]
                    # Check if there is a higher high on price
                    if not wait_for_stoch_cross and \
                        max(past_row['close'], past_row['open']) > max(row['close'], row['open']):
                        # Divergence found!
                        wait_for_stoch_cross = True
                        potential_div['t2'] = row.name
                        potential_div['t2_idx'] = idx
                        potential_div['t2_rsi'] = row['rsi']
                        true_divergence = potential_div
                    
    # Remove all positions with threshold < 0 (bullish) or > 1 (bearish)
    running_bullish_divergences = [d for d in running_bullish_divergences if d['threshold'] > 0]
    running_bearish_divergences = [d for d in running_bearish_divergences if d['threshold'] < 100]
                
    # Save new lows / highs on RSI
    if (row['rsi'] < fin_data.iloc[idx-1]['rsi']) and (row['rsi'] < fin_data.iloc[idx+1]['rsi']):
        new_potential_div = {}
        new_potential_div['t1'] = row.name
        new_potential_div['t1_idx'] = idx
        new_potential_div['t1_rsi'] = row['rsi']
        new_potential_div['slope'] = 0
        new_potential_div['threshold'] = row['rsi']
        running_bullish_divergences.append(new_potential_div)
    if (row['rsi'] > fin_data.iloc[idx-1]['rsi']) and (row['rsi'] > fin_data.iloc[idx+1]['rsi']):
        new_potential_div = {}
        new_potential_div['t1'] = row.name
        new_potential_div['t1_idx'] = idx
        new_potential_div['t1_rsi'] = row['rsi']
        new_potential_div['slope'] = 0
        new_potential_div['threshold'] = row['rsi']
        running_bearish_divergences.append(new_potential_div)
        
    if wait_for_stoch_cross:
        # Check for cross of stochastic RSI
        old_stoch_delta = fin_data.iloc[idx-1]['stoch_k'] - fin_data.iloc[idx-1]['stoch_d']
        new_stoch_delta = fin_data.iloc[idx]['stoch_k'] - fin_data.iloc[idx]['stoch_d']
        if old_stoch_delta * new_stoch_delta < 0:
            # Cross found! Place trade.
            current_pattern = {
                'divergence_timeframe': (true_divergence['t1'], true_divergence['t2'])
            }
            current_trade = {
                'entry_time': row.name,
                'entry_price': row['close'],
                'take_profit': None,
                'stop_loss': None,
                'exit_time': None,
                'win': None
            }
            # Price below EMA 200 -> go short; above EMA 200 -> go long
            go_long = True
            if current_trade['entry_price'] < fin_data.iloc[idx]['ema']:
                go_long = False
            # Look for nearest swing low/high
            idx_swing_low = idx
            while True:
                surrounding_idx = [
                    idx_swing_low + j for j in range(-swing_low_margin, swing_low_margin+1) if j != 0
                ]
                valid_idx = set(surrounding_idx).intersection(range(1, idx+1))
                if go_long: # go long
                    if fin_data.iloc[idx_swing_low]['low'] < current_trade['entry_price'] \
                        and fin_data.iloc[idx_swing_low]['low'] < fin_data.iloc[list(valid_idx)]['low'].min():
                        # Swing low found. Place stop loss and take profit.
                        current_trade['stop_loss'] = 0.999 * fin_data.iloc[idx_swing_low]['low']
                        current_trade['take_profit'] = current_trade['entry_price'] \
                            + 2 * (current_trade['entry_price'] - current_trade['stop_loss'])
                        break
                else: # go short
                    if fin_data.iloc[idx_swing_low]['high'] > current_trade['entry_price'] \
                        and fin_data.iloc[idx_swing_low]['high'] > fin_data.iloc[list(valid_idx)]['high'].max():
                        # Swing high found. Place stop loss and take profit.
                        current_trade['stop_loss'] = 1.001 * fin_data.iloc[idx_swing_low]['high']
                        current_trade['take_profit'] = current_trade['entry_price'] \
                            + 2 * (current_trade['entry_price'] - current_trade['stop_loss'])
                        break
                idx_swing_low = idx_swing_low-1
            # Find trade exit
            for idx_future in range(idx, len(fin_data)-1):
                # Is trade long or short?
                long = True
                if current_trade['stop_loss'] > current_trade['take_profit']:
                    long = False
                if (long and current_trade['stop_loss'] > fin_data.iloc[idx_future]['low']) or \
                   (not long and current_trade['stop_loss'] < fin_data.iloc[idx_future]['high']):
                    # Stopp loss target hit
                    current_trade['exit_time'] = fin_data.iloc[idx_future].name
                    current_trade['win'] = False
                    break
                if (long and current_trade['take_profit'] < fin_data.iloc[idx_future]['high']) or \
                   (not long and current_trade['take_profit'] > fin_data.iloc[idx_future]['low']):
                    # Take profit target hit
                    current_trade['exit_time'] = fin_data.iloc[idx_future].name
                    current_trade['win'] = True
                    break
                if idx_future == len(fin_data)-2:
                    current_trade['exit_time'] = fin_data.iloc[idx_future].name
                    current_trade['win'] = False
            
            results.add_trade_and_signal(**current_trade, **current_pattern)
            wait_for_stoch_cross = False

# %%
results.plot(start_time, end_time)
# Out:
# c:\users\robert\desktop\technischeanalysebot\newpull\venv\lib\site-packages\mplfinance\_arg_validators.py:35: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
running_divergences
# Out:
# [{'t1': Timestamp('2021-05-19 13:00:00'),
#   't1_idx': 2,
#   't1_rsi': 17.995602591425097,
#   'slope': -0.002820138879288812,
#   'threshold': 17.4400352322052,
#   't2': Timestamp('2021-05-23 08:30:00'),
#   't2_idx': 185,
#   't2_rsi': 17.479517176515245},
#  {'t1': Timestamp('2021-05-19 14:00:00'),
#   't1_idx': 4,
#   't1_rsi': 33.28653157248803,
#   'slope': -0.08733157124846842,
#   'threshold': 16.256875179036687,
#   't2': Timestamp('2021-05-21 15:30:00'),
#   't2_idx': 103,
#   't2_rsi': 27.961536149379597},
#  {'t1': Timestamp('2021-05-19 15:00:00'),
#   't1_idx': 6,
#   't1_rsi': 41.35000644923449,
#   'slope': -0.1825701281475939,
#   'threshold': 6.113971716748871},
#  {'t1': Timestamp('2021-05-20 00:30:00'),
#   't1_idx': 25,
#   't1_rsi': 37.88117401443021,
#   'slope': -0.12751035523696852,
#   'threshold': 15.694372203197684,
#   't2': Timestamp('2021-05-21 15:30:00'),
#   't2_idx': 103,
#   't2_rsi': 27.961536149379597},
# ...

# %%
for idx, row in fin_data.iterrows():
    if np.isnan(row['ema']) or np.isnan(row['rsi']) or \
       np.isnan(row['stoch_k']) or np.isnan(row['stoch_d']):
        continue
    if np.isnan
    print(row['ema'])
# Out:
#   File "<ipython-input-130-a04872675a20>", line 5
#     if np.isnan
#                ^
# SyntaxError: invalid syntax

# %%
results.evaluation(start_time, end_time)
# Out:
#  Win quantile0.5: 0.013428211631138106
#  Win mean: 0.02973017894421936
#  Loss quantile0.5: -0.01490609735011857
#  Loss mean: -0.021830673309932106
#  Gain avg: -0.15740666288052146
#
#  Buy&Hold 0.14596497448820192
#  Days: 12
#  Total Trades: 45
#  Winners: 16
#  Losses: 29
#  Win Percentage: 0.35555555555555557
#  Max Wins: 4
#  Max Losses: 10
#  Overall Gain: -0.15740666288052135
